# %% [markdown]
# <a href="https://colab.research.google.com/github/likhon15-4915/Research-Innovation/blob/main/Lumpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Lumpy skin disease data.csv')

# %%
df.head()
# Out:
#            x          y region     country reportingDate   cld   dtr    frs  \
# 0  90.380931  22.437184   Asia  Bangladesh     10/9/2020  41.6  12.8   0.00
# 1  87.854975  22.986757   Asia       India    20/12/2019  40.5  13.3   0.00
# 2  85.279935  23.610181   Asia       India    20/12/2019  27.3  13.6   0.08
# 3  81.564510  43.882221   Asia       China    25/10/2019  45.3  12.8  31.00
# 4  81.161057  43.834976   Asia       China    25/10/2019  38.8  13.2  31.00
#
#    pet   pre   tmn   tmp   tmx   vap   wet  elevation  dominant_land_cover  \
# 0  2.3   1.7  12.7  19.1  25.5  15.7  0.00        147                    2
# 1  2.4   0.0  13.2  19.8  26.5  16.3  0.00        145                    2
# 2  2.3   0.6   9.4  16.2  23.0  13.0  0.98        158                    2
# 3  0.4   8.8 -22.5 -16.1  -9.7   0.9  4.64        178                    2
# 4  0.4  10.5 -20.4 -13.8  -7.2   1.2  1.69        185                    3
#
#    X5_Ct_2010_Da  X5_Bf_2010_Da  lumpy
# ...

# %%
def plotChart(dataset, CTarget_0_1, IndepFeature):
    plt.style.use('dark_background')
    plt.figure(figsize=(20,5))
    plt.subplot(1,2,1)
    sns.distplot(dataset[dataset[CTarget_0_1]==0][IndepFeature],label='Not Suffered By Lumpy',hist=False,color='green')
    sns.distplot(dataset[dataset[CTarget_0_1]==1][IndepFeature],label="Suffered By Lumpy",hist=False,color='red')
    plt.grid(True)
    plt.legend()
    plt.show()

def plotGraph(dataset, feature):
    plt.style.use('Solarize_Light2')
    plt.figure(figsize=(15,10))
    plt.subplot(2,2,1)
    plt.title(f'{feature} Distribution Graph')
    sns.distplot(dataset[feature],color="red")

    plt.subplot(2,2,2)
    plt.title(f'{feature} Histogram Graph',color="red")
    sns.histplot(dataset[feature],color='red',kde=True,bins=10)

    plt.subplot(2,2,3)
    plt.title(f'{feature} BoxPlot')
    sns.boxplot(dataset[feature],color="red")
    plt.show()

# %%
df = df.drop('reportingDate', axis=1)

# %%
df
# Out:
#                x          y region     country   cld   dtr    frs  pet    pre  \
# 0      90.380931  22.437184   Asia  Bangladesh  41.6  12.8   0.00  2.3    1.7
# 1      87.854975  22.986757   Asia       India  40.5  13.3   0.00  2.4    0.0
# 2      85.279935  23.610181   Asia       India  27.3  13.6   0.08  2.3    0.6
# 3      81.564510  43.882221   Asia       China  45.3  12.8  31.00  0.4    8.8
# 4      81.161057  43.834976   Asia       China  38.8  13.2  31.00  0.4   10.5
# ...          ...        ...    ...         ...   ...   ...    ...  ...    ...
# 24798  20.250000 -16.750000    NaN         NaN  68.8  12.0   0.00  3.6  172.0
# 24799  20.750000 -16.750000    NaN         NaN  68.8  11.8   0.00  3.6  170.0
# 24800  21.250000 -16.750000    NaN         NaN  68.8  11.6   0.00  3.6  167.5
# 24801  21.750000 -16.750000    NaN         NaN  68.8  11.5   0.00  3.6  169.5
# 24802  22.250000 -16.750000    NaN         NaN  67.5  11.4   0.00  3.7  172.1
#
# ...

# %%
df.isnull().sum()
# Out:
# x                          0
# y                          0
# region                 21764
# country                21764
# cld                        0
# dtr                        0
# frs                        0
# pet                        0
# pre                        0
# tmn                        0
# tmp                        0
# tmx                        0
# vap                        0
# wet                        0
# elevation                  0
# dominant_land_cover        0
# X5_Ct_2010_Da              0
# X5_Bf_2010_Da              0
# lumpy                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1077

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (23726, 19)

# %%
df.isnull().sum()
# Out:
# x                          0
# y                          0
# region                 21764
# country                21764
# cld                        0
# dtr                        0
# frs                        0
# pet                        0
# pre                        0
# tmn                        0
# tmp                        0
# tmx                        0
# vap                        0
# wet                        0
# elevation                  0
# dominant_land_cover        0
# X5_Ct_2010_Da              0
# X5_Bf_2010_Da              0
# lumpy                      0
# dtype: int64

# %%
df.rename(columns={"x":"Longitude" , "y":"Latitude", "cld":"Monthly Cloud Cover", "dtr":"Diurnal Temperature Range", "frs":"Frost Day Frequency", "pet":"Potential EvapoTranspiration", "pre":"Precipitation", "tmn":"Minimum Temperature", "tmp":"Mean Temperature", "tmx":"Maximum Temperature", "vap":"Vapour Pressure", "wet":"Wet Day Frequency"},inplace=True,errors="raise")

# %%
df.head()
# Out:
#    Longitude   Latitude region     country  Monthly Cloud Cover  \
# 0  90.380931  22.437184   Asia  Bangladesh                 41.6
# 1  87.854975  22.986757   Asia       India                 40.5
# 2  85.279935  23.610181   Asia       India                 27.3
# 3  81.564510  43.882221   Asia       China                 45.3
# 4  81.161057  43.834976   Asia       China                 38.8
#
#    Diurnal Temperature Range  Frost Day Frequency  \
# 0                       12.8                 0.00
# 1                       13.3                 0.00
# 2                       13.6                 0.08
# 3                       12.8                31.00
# 4                       13.2                31.00
#
#    Potential EvapoTranspiration  Precipitation  Minimum Temperature  \
# 0                           2.3            1.7                 12.7
# 1                           2.4            0.0                 13.2
# ...

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
from shapely.geometry import Point
import plotly.express as px

# %%
z = np.abs(stats.zscore(df['Monthly Cloud Cover']))
out=np.where(z>3)[0]
print('Monthly Cloud Cover'+ " " + str(out))
df['Monthly Cloud Cover'] = df['Monthly Cloud Cover'].drop(out)
# Out:
# Monthly Cloud Cover [17665]

# %%
z = np.abs(stats.zscore(df['Diurnal Temperature Range']))
out = np.where(z>3)[0]
print('Diurnal Temperature Range'+ " " + str(out))
df['Diurnal Temperature Range'] = df['Diurnal Temperature Range'].drop(out)
# Out:
# Diurnal Temperature Range [17840 17841 17842 17843 17856 17857 17858 17859 17872 17873 17874 17875
#  17889 19403 19437 19438 19441 19442 19443 19444 19472 19473 19474 19475
#  19476 19477 19478 19479 19480 19481 19510 19609 19610 19664 19665 19827
#  20683 20691 20697 22055 22056 22057 22100 22101 22102 22103 22144 22145
#  22146 22147 22148 22187 22188 22189 22190 22191 22192 22233 22234 22235
#  22236 22237 22238 22279 22280 22281 22282 22283 22284 22324 22325 22326
#  22327 22328 22329 22371 22372 22373 22374 22375 22420 22421 22422 22423
#  22470 22471]

# %%
z = np.abs(stats.zscore(df['Frost Day Frequency']))
out = np.where(z>3)[0]
print('Frost Day Frequency'+ " " + str(out))
df['Frost Day Frequency'] = df['Frost Day Frequency'].drop(out)
# Out:
# Frost Day Frequency []

# %%
z = np.abs(stats.zscore(df['Mean Temperature']))
out = np.where(z>3)[0]
print('Mean Temperature'+ " " + str(out))
df['Mean Temperature'] = df['Mean Temperature'].drop(out)
# Out:
# Mean Temperature []

# %%
z = np.abs(stats.zscore(df['Minimum Temperature']))
out = np.where(z>3)[0]
print('Minimum Temperature'+ " " + str(out))
df['Minimum Temperature'] = df['Minimum Temperature'].drop(out)
# Out:
# Minimum Temperature []

# %%
z = np.abs(stats.zscore(df['Maximum Temperature']))
out = np.where(z>3)[0]
print('Maximum Temperature'+ " " + str(out))
df['Maximum Temperature'] = df['Maximum Temperature'].drop(out)
# Out:
# Maximum Temperature []

# %%
z = np.abs(stats.zscore(df['Wet Day Frequency']))
out = np.where(z>3)[0]
print('Wet Day Frequency'+ " " + str(out))
df['Wet Day Frequency'] = df['Wet Day Frequency'].drop(out)
# Out:
# Wet Day Frequency [23240 23255 23256]

# %%
z = np.abs(stats.zscore(df['dominant_land_cover']))
out = np.where(z>3)[0]
print('dominant_land_cover'+ " " + str(out))
df['dominant_land_cover'] = df['dominant_land_cover'].drop(out)
# Out:
# dominant_land_cover []

# %%
df = df.fillna(method='bfill')
df.isnull().sum()
# Out:
# Longitude                           0
# Latitude                            0
# region                          21764
# country                         21764
# Monthly Cloud Cover                 0
# Diurnal Temperature Range           0
# Frost Day Frequency                 0
# Potential EvapoTranspiration        0
# Precipitation                       0
# Minimum Temperature                 0
# Mean Temperature                    0
# Maximum Temperature                 0
# Vapour Pressure                     0
# Wet Day Frequency                   0
# elevation                           0
# dominant_land_cover                 0
# X5_Ct_2010_Da                       0
# X5_Bf_2010_Da                       0
# lumpy                               0
# dtype: int64

# %%
geolocation = df.loc[df['lumpy'] != 0][['Longitude', 'Latitude', 'country']]
geolocation.head()
# Out:
#    Longitude   Latitude     country
# 0  90.380931  22.437184  Bangladesh
# 1  87.854975  22.986757       India
# 2  85.279935  23.610181       India
# 3  81.564510  43.882221       China
# 4  81.161057  43.834976       China

# %%
fig = px.scatter_geo(geolocation,lat='Latitude',lon='Longitude')
fig.update_layout(title = 'Lumpy Skin Disease Area', title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Meteorological Features
# Univariate Data Analysis
# Region **bold text**

# %%
df['region'].value_counts()
# Out:
# region
# Europe    1368
# Asia       516
# Africa      78
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,40))
plt.subplot(121)
df['region'].value_counts().plot.pie(autopct="%2f",explode=(0.02,0,0),title = "Region wise Spread in Percentage")
plt.show()

# %%
pd.DataFrame(df.groupby(['region','country'])['country'].count()).rename(columns={'country' : "CountryCount"})
# Out:
#                                     CountryCount
# region country
# Africa Angola                                  1
#        Burundi                                 2
#        Djibouti                                1
#        Egypt                                  10
#        Guinea                                  5
#        Namibia                                59
# Asia   Armenia                                 1
#        Azerbaijan                             16
#        Bangladesh                             10
#        Bhutan                                  7
#        China                                  61
#        Cyprus                                  2
#        Georgia                                 8
#        Hong Kong, SAR                          1
#        India                                   9
#        Iran  (Islamic Republic of)             5
#        Iraq                                   22
#        Israel                                 53
# ...

# %%
pd.DataFrame(df.groupby(['region','country'])['country'].count()).plot(kind="bar",color="green")
# Out:
# <Axes: xlabel='region,country'>

# %%
plotGraph(df,'Monthly Cloud Cover')

# %%
plotGraph(df,'Diurnal Temperature Range')

# %%
plotGraph(df,'Frost Day Frequency')

# %%
plotGraph(df,'Potential EvapoTranspiration')

# %%
plotGraph(df,'Precipitation')

# %%
plotGraph(df,'Mean Temperature')

# %%
plotGraph(df,'Minimum Temperature')

# %%
plotChart(df,'lumpy','Monthly Cloud Cover')

# %% [markdown]
# **Model**

# %%
df
# Out:
#        Longitude   Latitude region     country  Monthly Cloud Cover  \
# 0      90.380931  22.437184   Asia  Bangladesh                 41.6
# 1      87.854975  22.986757   Asia       India                 40.5
# 2      85.279935  23.610181   Asia       India                 27.3
# 3      81.564510  43.882221   Asia       China                 45.3
# 4      81.161057  43.834976   Asia       China                 38.8
# ...          ...        ...    ...         ...                  ...
# 24798  20.250000 -16.750000    NaN         NaN                 68.8
# 24799  20.750000 -16.750000    NaN         NaN                 68.8
# 24800  21.250000 -16.750000    NaN         NaN                 68.8
# 24801  21.750000 -16.750000    NaN         NaN                 68.8
# 24802  22.250000 -16.750000    NaN         NaN                 67.5
#
#        Diurnal Temperature Range  Frost Day Frequency  \
# 0                           12.8                 0.00
# ...

# %%
data = df.drop(['region', 'country', 'Diurnal Temperature Range', 'Frost Day Frequency', 'elevation', 'dominant_land_cover', 'X5_Ct_2010_Da', 'X5_Bf_2010_Da'], axis=1)

# %%
data.head()
# Out:
#    Longitude   Latitude  Monthly Cloud Cover  Potential EvapoTranspiration  \
# 0  90.380931  22.437184                 41.6                           2.3
# 1  87.854975  22.986757                 40.5                           2.4
# 2  85.279935  23.610181                 27.3                           2.3
# 3  81.564510  43.882221                 45.3                           0.4
# 4  81.161057  43.834976                 38.8                           0.4
#
#    Precipitation  Minimum Temperature  Mean Temperature  Maximum Temperature  \
# 0            1.7                 12.7              19.1                 25.5
# 1            0.0                 13.2              19.8                 26.5
# 2            0.6                  9.4              16.2                 23.0
# 3            8.8                -22.5             -16.1                 -9.7
# 4           10.5                -20.4             -13.8                 -7.2
#
#    Vapour Pressure  Wet Day Frequency  lumpy
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(data)
scaler.transform(data)
# Out:
# array([[ 0.20464054, -1.24351174, -0.88494951, ...,  2.42451703,
#         -1.33923345,  3.3305799 ],
#        [ 0.1454314 , -1.21536124, -0.94128946, ...,  2.54480629,
#         -1.33923345,  3.3305799 ],
#        [ 0.08507172, -1.1834279 , -1.61736887, ...,  1.88321533,
#         -1.18353667,  3.3305799 ],
#        ...,
#        [-1.4158085 , -3.25077757,  0.50818383, ...,  4.06847032,
#          1.18210114, -0.30024801],
#        [-1.40408835, -3.25077757,  0.50818383, ...,  4.12861495,
#          1.25041707, -0.30024801],
#        [-1.39236821, -3.25077757,  0.44160025, ...,  4.18875959,
#          1.30920055, -0.30024801]])

# %%
X = data.iloc[:, :-1]

# %%
y = data.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
print("X_Train = ", x_train.shape)
print("X_Test = ", x_test.shape)
print("y_train = ", y_train.shape)
print("y_test = ", y_test.shape)
# Out:
# X_Train =  (16608, 10)
# X_Test =  (7118, 10)
# y_train =  (16608,)
# y_test =  (7118,)

# %% [markdown]
# # Linaer Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(x_train, y_train)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score

results = model.predict(x_test)
print("MSE: ", np.sqrt(mean_squared_error(y_test,results)))
print("R-Squared Error: ", r2_score(y_test, results))
print("Training Score: ", model.score(x_train, y_train))
print("Testing Score: ", model.score(x_test, y_test))
#print("Accuracy: ", model.accuracy_score(y_test, results))
# Out:
# MSE:  0.24353750589731724
# R-Squared Error:  0.26270152623104115
# Training Score:  0.24719561335687956
# Testing Score:  0.26270152623104115

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators = 100)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
results = model.predict(x_test)
print("MSE: ", np.sqrt(mean_squared_error(y_test,results)))
print("R-Squared Error: ", r2_score(y_test, results))
print("Training Score: ", model.score(x_train, y_train))
print("Testing Score: ", model.score(x_test, y_test))
# Out:
# MSE:  0.16251742509293196
# R-Squared Error:  0.6716693001481946
# Training Score:  1.0
# Testing Score:  0.9735880865411632

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
from sklearn import svm
model = svm.SVC(kernel='linear') # Linear Kernel
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
results = model.predict(x_test)
print("MSE: ", np.sqrt(mean_squared_error(y_test,results)))
print("R-Squared Error: ", r2_score(y_test, results))
print("Training Score: ", model.score(x_train, y_train))
print("Testing Score: ", model.score(x_test, y_test))
# Out:
# MSE:  0.22983434668837793
# R-Squared Error:  0.3433386002963893
# Training Score:  0.95002408477842
# Testing Score:  0.9471761730823265

# %%
from sklearn import svm
model = svm.SVC(kernel='poly') # poly Kernel
model.fit(x_train, y_train)
# Out:
# SVC(kernel='poly')

# %%
results = model.predict(x_test)
print("MSE: ", np.sqrt(mean_squared_error(y_test,results)))
print("R-Squared Error: ", r2_score(y_test, results))
print("Training Score: ", model.score(x_train, y_train))
print("Testing Score: ", model.score(x_test, y_test))
# Out:
# MSE:  0.22426552720579074
# R-Squared Error:  0.3747745183673069
# Training Score:  0.9533357418111753
# Testing Score:  0.9497049733071088

# %%
from sklearn import svm
model = svm.SVC(kernel='rbf') # RBF Kernel
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
results = model.predict(x_test)
print("MSE: ", np.sqrt(mean_squared_error(y_test,results)))
print("R-Squared Error: ", r2_score(y_test, results))
print("Training Score: ", model.score(x_train, y_train))
print("Testing Score: ", model.score(x_test, y_test))
# Out:
# MSE:  0.2146633635523014
# R-Squared Error:  0.42716771515216945
# Training Score:  0.9564065510597303
# Testing Score:  0.9539196403484125

# %%
from sklearn import svm
model = svm.SVC(kernel='sigmoid') # Sigmoid Kernel
model.fit(x_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
results = model.predict(x_test)
print("MSE: ", np.sqrt(mean_squared_error(y_test,results)))
print("R-Squared Error: ", r2_score(y_test, results))
print("Training Score: ", model.score(x_train, y_train))
print("Testing Score: ", model.score(x_test, y_test))
# Out:
# MSE:  0.4050815187194945
# R-Squared Error:  -1.0398417948239822
# Training Score:  0.8476637764932563
# Testing Score:  0.8359089631919079

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model = model.fit(x_train, y_train)

# %%
results = model.predict(x_test)
print("MSE: ", np.sqrt(mean_squared_error(y_test,results)))
print("R-Squared Error: ", r2_score(y_test, results))
print("Training Score: ", model.score(x_train, y_train))
print("Testing Score: ", model.score(x_test, y_test))
# Out:
# MSE:  0.15902201812271916
# R-Squared Error:  0.6856408192908247
# Training Score:  1.0
# Testing Score:  0.9747119977521775
